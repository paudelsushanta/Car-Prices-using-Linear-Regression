# %% [markdown]
# # Predicting Second Hand Car prices based on Mileage and Age

# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('carprices.csv')
data.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %% [markdown]
# # Explore relationships between available parameters

# %%
plt.figure(figsize=(25,10))
plt.xlabel('Mileage')
plt.ylabel('Selling Price')
plt.scatter(data['Mileage'],data['Sell Price($)'])
plt.title('Car Mileage Vs Sell Price ($)',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Car Mileage Vs Sell Price ($)')

# %%
plt.figure(figsize=(25,10))
plt.xlabel('Age')
plt.ylabel('Selling Price')
plt.scatter(data['Mileage'],data['Sell Price($)'])
plt.title('Car Age Vs Sell Price ($)',fontsize=25)
# Out:
# Text(0.5, 1.0, 'Car Age Vs Sell Price ($)')

# %% [markdown]
# ## We can  see a linear relationship between our dependant (i.e. Sell Price) and independant variables (i.e. car age and car mileage)
# ## So we use Linear Regression Model

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train1=np.arange(0,len(X_train),1)
X_test1=np.arange(0,len(X_test),1)

plt.scatter(X_train1,y_train,color='r',label='Training Data')
plt.scatter(X_test1,y_test,color='g',label='Test data')
plt.legend()
plt.title('Test vs Train Data Split')
# Out:
# Text(0.5, 1.0, 'Test vs Train Data Split')

# %% [markdown]
# ### Running Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 9     67000         6
# 10    83000         7
# 14    82450         7
# 4     46000         4
# 7     72000         6
# 11    79000         7

# %%
clf.predict(X_test)
prediction=clf.predict(X_test)

# %%
y_test
# Out:
# 9     22000
# 10    18700
# 14    19400
# 4     31500
# 7     19300
# 11    19500
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test, y_test)
# Out:
# 0.7557095227271362

# %%
plt.plot(X_test.iloc[:, 0],prediction,color='r')
plt.scatter(X_test.iloc[:, 0],y_test,color='g')
